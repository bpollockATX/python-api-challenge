# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as stats
import datetime
import json
from api_keys import api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# Output File (CSV)
output_data_file = "output_data/cities.csv"
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 653

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
count = 0
city_names = []
clouds = []
countries = []
dates = []
humidities = []
latitudes = []
longitudes = []
max_temps = []
wind_speeds = []
for city in cities:
    try:
        query = f"{base_url}appid={api_key}&units={units}&q="
        response = requests.get(query + city).json()
        count = count + 1
        print(f"Processing Record {count} |  {city}")
        country = response["sys"]["country"]
        latitude = response["coord"]["lat"]
        longitude = response["coord"]["lon"]
        date = response["dt"]
        temp = 1.8*(response["main"]["temp_max"]) + 32
        humidity = response["main"]["humidity"]
        cloudiness = response["clouds"]["all"]
        wind_speed = 2.236936*(response["wind"]["speed"])
        city_names.append(city)
        latitudes.append(latitude)
        longitudes.append(longitude)
        countries.append(country)
        dates.append(date)
        max_temps.append(temp)
        humidities.append(humidity)
        clouds.append(cloudiness)
        wind_speeds.append(wind_speed)
        
        
    except KeyError:
        print("Couldn't locate data. Skipping city!")
           
weather_data = {"City": city_names,
                "Cloudiness": clouds,
                "Country": countries,
                "Date": dates,
                "Humidity": humidities,
                "Lat": latitudes,
                "Lng": longitudes,
                "Max Temp": max_temps,
                "Wind Speeds": wind_speeds}
weather_reports = pd.DataFrame(weather_data)
weather_reports[["Max Temp", "Wind Speeds"]] = weather_reports[["Max Temp", "Wind Speeds"]].apply(pd.to_numeric)
weather_reports["Max Temp"] = weather_reports["Max Temp"].map("{:.2f}".format)
weather_reports["Wind Speeds"] = weather_reports["Wind Speeds"].map("{:.2f}".format)
# Out:
# Processing Record 1 |  bluff
# Processing Record 2 |  punta arenas
# Processing Record 3 |  mataura
# Processing Record 4 |  gap
# Processing Record 5 |  grand river south east
# Couldn't locate data. Skipping city!
# Processing Record 6 |  addis zemen
# Couldn't locate data. Skipping city!
# Processing Record 7 |  kahului
# Processing Record 8 |  avarua
# Processing Record 9 |  marcona
# Couldn't locate data. Skipping city!
# Processing Record 10 |  martapura
# Processing Record 11 |  dikson
# Processing Record 12 |  khatanga
# Processing Record 13 |  saleaula
# Couldn't locate data. Skipping city!
# Processing Record 14 |  diffa
# Processing Record 15 |  evensk
# Processing Record 16 |  vaini
# Processing Record 17 |  totma
# Processing Record 18 |  mys shmidta
# Couldn't locate data. Skipping city!
# Processing Record 19 |  hilo
# Processing Record 20 |  jamestown
# Processing Record 21 |  kangaatsiaq
# Processing Record 22 |  sao joao da barra
# Processing Record 23 |  bandarbeyla
# Processing Record 24 |  rikitea
# Processing Record 25 |  aflu
# Couldn't locate data. Skipping city!
# Processing Record 26 |  oistins
# Processing Record 27 |  port alfred
# Processing Record 28 |  ushuaia
# Processing Record 29 |  palabuhanratu
# Couldn't locate data. Skipping city!
# Processing Record 30 |  san vicente
# Processing Record 31 |  shahr-e babak
# Processing Record 32 |  isangel
# Processing Record 33 |  yulara
# Processing Record 34 |  rohru
# Processing Record 35 |  walla walla
# Processing Record 36 |  albany
# Processing Record 37 |  nabire
# Processing Record 38 |  bredasdorp
# Processing Record 39 |  baijiantan
# Processing Record 40 |  xapuri
# Processing Record 41 |  arraial do cabo
# Processing Record 42 |  busselton
# Processing Record 43 |  tiksi
# Processing Record 44 |  esperance
# Processing Record 45 |  melilla
# Processing Record 46 |  orastioara de sus
# Processing Record 47 |  puerto narino
# Processing Record 48 |  faanui
# Processing Record 49 |  kapaa
# Processing Record 50 |  severo-kurilsk
# Processing Record 51 |  skalistyy
# Couldn't locate data. Skipping city!
# Processing Record 52 |  jaguaquara
# Processing Record 53 |  qaanaaq
# Processing Record 54 |  matara
# Processing Record 55 |  east london
# Processing Record 56 |  canico
# Processing Record 57 |  hithadhoo
# Processing Record 58 |  kieta
# Processing Record 59 |  sao filipe
# Processing Record 60 |  geraldton
# Processing Record 61 |  laguna
# Processing Record 62 |  vestmannaeyjar
# Processing Record 63 |  port blair
# Processing Record 64 |  butaritari
# Processing Record 65 |  port elizabeth
# Processing Record 66 |  kirakira
# Processing Record 67 |  zhezkazgan
# Processing Record 68 |  jizan
# Processing Record 69 |  tessalit
# Processing Record 70 |  nikolskoye
# Processing Record 71 |  talnakh
# Processing Record 72 |  skovorodino
# Processing Record 73 |  havre-saint-pierre
# Processing Record 74 |  tazovskiy
# Processing Record 75 |  tasiilaq
# Processing Record 76 |  jiexiu
# Processing Record 77 |  aklavik
# Processing Record 78 |  tsihombe
# Couldn't locate data. Skipping city!
# Processing Record 79 |  acuna
# Couldn't locate data. Skipping city!
# Processing Record 80 |  savannakhet
# Processing Record 81 |  manado
# Processing Record 82 |  roma
# Processing Record 83 |  cidreira
# Processing Record 84 |  belle fourche
# Processing Record 85 |  barentsburg
# Couldn't locate data. Skipping city!
# Processing Record 86 |  nusaybin
# Processing Record 87 |  atuona
# Processing Record 88 |  cape town
# Processing Record 89 |  ucluelet
# Processing Record 90 |  bethanien
# Processing Record 91 |  coihaique
# Processing Record 92 |  katsuura
# Processing Record 93 |  fortuna
# Processing Record 94 |  victoria
# Processing Record 95 |  tawkar
# Couldn't locate data. Skipping city!
# Processing Record 96 |  parakou
# Processing Record 97 |  puerto ayora
# Processing Record 98 |  chuy
# Processing Record 99 |  yerbogachen
# Processing Record 100 |  vila velha
# Processing Record 101 |  kearney
# Processing Record 102 |  alofi
# Processing Record 103 |  fort william
# Processing Record 104 |  derzhavinsk
# Processing Record 105 |  dolbeau
# Couldn't locate data. Skipping city!
# Processing Record 106 |  gondar
# Processing Record 107 |  meulaboh
# Processing Record 108 |  chongwe
# Processing Record 109 |  ha giang
# Processing Record 110 |  new norfolk
# Processing Record 111 |  batticaloa
# Processing Record 112 |  samusu
# Couldn't locate data. Skipping city!
# Processing Record 113 |  sorvag
# Couldn't locate data. Skipping city!
# Processing Record 114 |  doka
# Processing Record 115 |  makakilo city
# Processing Record 116 |  hermanus
# Processing Record 117 |  yellowknife
# Processing Record 118 |  bombo
# Processing Record 119 |  illoqqortoormiut
# Couldn't locate data. Skipping city!
# Processing Record 120 |  kaitangata
# Processing Record 121 |  obuasi
# Processing Record 122 |  mahebourg
# Processing Record 123 |  nizhneyansk
# Couldn't locate data. Skipping city!
# Processing Record 124 |  penzance
# Processing Record 125 |  kazalinsk
# Couldn't locate data. Skipping city!
# Processing Record 126 |  chalmette
# Processing Record 127 |  half moon bay
# Processing Record 128 |  cody
# Processing Record 129 |  shumskiy
# Processing Record 130 |  sault sainte marie
# Processing Record 131 |  khasan
# Processing Record 132 |  bhadravati
# Processing Record 133 |  carnarvon
# Processing Record 134 |  shushtar
# Processing Record 135 |  alice springs
# Processing Record 136 |  willowmore
# Processing Record 137 |  serebryanyy bor
# Processing Record 138 |  rosenheim
# Processing Record 139 |  sabang
# Processing Record 140 |  newnan
# Processing Record 141 |  tura
# Processing Record 142 |  podbelsk
# Couldn't locate data. Skipping city!
# Processing Record 143 |  barrow
# Processing Record 144 |  gidole
# Processing Record 145 |  oranjemund
# Processing Record 146 |  pangai
# Processing Record 147 |  horta
# Processing Record 148 |  palatka
# Processing Record 149 |  bethel
# Processing Record 150 |  kakching
# Processing Record 151 |  ostrovnoy
# Processing Record 152 |  jian
# Processing Record 153 |  los llanos de aridane
# Processing Record 154 |  cherskiy
# Processing Record 155 |  bayaguana
# Processing Record 156 |  mar del plata
# Processing Record 157 |  codrington
# Processing Record 158 |  torbay
# Processing Record 159 |  ornskoldsvik
# Processing Record 160 |  gaoua
# Processing Record 161 |  farafangana
# Processing Record 162 |  hualmay
# Processing Record 163 |  ahipara
# Processing Record 164 |  mala vyska
# Processing Record 165 |  iaciara
# Processing Record 166 |  nagsabaran
# Couldn't locate data. Skipping city!
# Processing Record 167 |  nelson bay
# Processing Record 168 |  ongandjera
# Processing Record 169 |  milkovo
# Processing Record 170 |  attawapiskat
# Couldn't locate data. Skipping city!
# Processing Record 171 |  sarakhs
# Processing Record 172 |  russell
# Processing Record 173 |  chumikan
# Processing Record 174 |  vanimo
# Processing Record 175 |  dajabon
# Processing Record 176 |  berlevag
# Processing Record 177 |  cockburn town
# Processing Record 178 |  vaitupu
# Couldn't locate data. Skipping city!
# Processing Record 179 |  luderitz
# Processing Record 180 |  saint-philippe
# Processing Record 181 |  westport
# Processing Record 182 |  athabasca
# Processing Record 183 |  broome
# Processing Record 184 |  anchorage
# Processing Record 185 |  vardo
# Processing Record 186 |  caluquembe
# Processing Record 187 |  uvalde
# Processing Record 188 |  lebu
# Processing Record 189 |  ankang
# Processing Record 190 |  myre
# Processing Record 191 |  mykhaylivka
# Processing Record 192 |  lac du bonnet
# Processing Record 193 |  hasaki
# Processing Record 194 |  coahuayana
# Processing Record 195 |  sajanan
# Processing Record 196 |  bambous virieux
# Processing Record 197 |  tateyama
# Processing Record 198 |  kargat
# Processing Record 199 |  waiuku
# Processing Record 200 |  ketchikan
# Processing Record 201 |  lutkun
# Processing Record 202 |  dunedin
# Processing Record 203 |  englewood
# Processing Record 204 |  sheltozero
# Processing Record 205 |  ilulissat
# Processing Record 206 |  lasa
# Processing Record 207 |  smithers
# Processing Record 208 |  bur gabo
# Couldn't locate data. Skipping city!
# Processing Record 209 |  pallasovka
# Processing Record 210 |  fairbanks
# Processing Record 211 |  urumqi
# Processing Record 212 |  longyearbyen
# Processing Record 213 |  burnie
# Processing Record 214 |  chokurdakh
# Processing Record 215 |  nizhniy tsasuchey
# Processing Record 216 |  arroyo
# Processing Record 217 |  hobart
# Processing Record 218 |  gambela
# Processing Record 219 |  flinders
# Processing Record 220 |  komsomolskiy
# Processing Record 221 |  tuatapere
# Processing Record 222 |  myitkyina
# Processing Record 223 |  bafia
# Processing Record 224 |  menongue
# Processing Record 225 |  taolanaro
# Couldn't locate data. Skipping city!
# Processing Record 226 |  casambalangan
# Processing Record 227 |  saskylakh
# Processing Record 228 |  vila franca do campo
# Processing Record 229 |  port-gentil
# Processing Record 230 |  kununurra
# Processing Record 231 |  batemans bay
# Processing Record 232 |  cairns
# Processing Record 233 |  sibolga
# Processing Record 234 |  chapais
# Processing Record 235 |  warrnambool
# Processing Record 236 |  zyryanskoye
# Processing Record 237 |  halalo
# Couldn't locate data. Skipping city!
# Processing Record 238 |  kars
# Processing Record 239 |  trenggalek
# Processing Record 240 |  caravelas
# Processing Record 241 |  tommot
# Processing Record 242 |  hajnowka
# Processing Record 243 |  batavia
# Processing Record 244 |  thompson
# Processing Record 245 |  nishihara
# Processing Record 246 |  sola
# Processing Record 247 |  paranga
# Processing Record 248 |  pisco
# Processing Record 249 |  sambava
# Processing Record 250 |  ferrol
# Processing Record 251 |  wewak
# Processing Record 252 |  praia
# Processing Record 253 |  banda aceh
# Processing Record 254 |  peremyshl
# Processing Record 255 |  magan
# Processing Record 256 |  saint george
# Processing Record 257 |  kimbe
# Processing Record 258 |  hamm
# Processing Record 259 |  kiama
# Processing Record 260 |  quatre cocos
# Processing Record 261 |  agsu
# Couldn't locate data. Skipping city!
# Processing Record 262 |  la romana
# Processing Record 263 |  ronne
# Processing Record 264 |  provideniya
# Processing Record 265 |  kjollefjord
# Processing Record 266 |  port hawkesbury
# Processing Record 267 |  castro
# Processing Record 268 |  bhainsdehi
# Processing Record 269 |  bay roberts
# Processing Record 270 |  ormara
# Processing Record 271 |  houma
# Processing Record 272 |  lubao
# Processing Record 273 |  yendi
# Processing Record 274 |  belushya guba
# Couldn't locate data. Skipping city!
# Processing Record 275 |  bukoba
# Processing Record 276 |  ankazoabo
# Processing Record 277 |  kawalu
# Processing Record 278 |  champerico
# Processing Record 279 |  hami
# Processing Record 280 |  saldanha
# Processing Record 281 |  georgetown
# Processing Record 282 |  adrar
# Processing Record 283 |  bilibino
# Processing Record 284 |  riyadh
# Processing Record 285 |  faya
# Processing Record 286 |  rapar
# Processing Record 287 |  palmares do sul
# Processing Record 288 |  marawi
# Processing Record 289 |  mirina
# Couldn't locate data. Skipping city!
# Processing Record 290 |  bassar
# Processing Record 291 |  touros
# Processing Record 292 |  vanavara
# Processing Record 293 |  diego de almagro
# Processing Record 294 |  puerto carreno
# Processing Record 295 |  havelock
# Processing Record 296 |  along
# Processing Record 297 |  humaita
# Processing Record 298 |  alterosa
# Processing Record 299 |  kargil
# Processing Record 300 |  kodiak
# Processing Record 301 |  olga
# Processing Record 302 |  talara
# Processing Record 303 |  upernavik
# Processing Record 304 |  beringovskiy
# Processing Record 305 |  louisbourg
# Couldn't locate data. Skipping city!
# Processing Record 306 |  jibuti
# Processing Record 307 |  camacha
# Processing Record 308 |  kuche
# Couldn't locate data. Skipping city!
# Processing Record 309 |  canutama
# Processing Record 310 |  sentyabrskiy
# Couldn't locate data. Skipping city!
# Processing Record 311 |  cabo san lucas
# Processing Record 312 |  iqaluit
# Processing Record 313 |  ndele
# Processing Record 314 |  kawana waters
# Couldn't locate data. Skipping city!
# Processing Record 315 |  madisonville
# Processing Record 316 |  darnah
# Processing Record 317 |  padang
# Processing Record 318 |  stepnoye
# Processing Record 319 |  buala
# Processing Record 320 |  port macquarie
# Processing Record 321 |  dudinka
# Processing Record 322 |  teguldet
# Processing Record 323 |  clyde river
# Processing Record 324 |  kismayo
# Processing Record 325 |  mount isa
# Processing Record 326 |  havoysund
# Processing Record 327 |  santarem
# Processing Record 328 |  constitucion
# Processing Record 329 |  andenes
# Processing Record 330 |  arslev
# Processing Record 331 |  izumo
# Processing Record 332 |  itoman
# Processing Record 333 |  ghanzi
# Processing Record 334 |  pevek
# Processing Record 335 |  chivay
# Processing Record 336 |  fort myers beach
# Processing Record 337 |  kysyl-syr
# Processing Record 338 |  tori
# Processing Record 339 |  rudnyy
# Processing Record 340 |  muzhi
# Processing Record 341 |  guerrero negro
# Processing Record 342 |  finnsnes
# Processing Record 343 |  ilinsko-podomskoye
# Couldn't locate data. Skipping city!
# Processing Record 344 |  bozeman
# Processing Record 345 |  amderma
# Couldn't locate data. Skipping city!
# Processing Record 346 |  srivardhan
# Processing Record 347 |  apiai
# Processing Record 348 |  tagusao
# Processing Record 349 |  yumen
# Processing Record 350 |  port lincoln
# Processing Record 351 |  grindavik
# Processing Record 352 |  akhmim
# Processing Record 353 |  ban phaeo
# Processing Record 354 |  den helder
# Processing Record 355 |  guicheng
# Couldn't locate data. Skipping city!
# Processing Record 356 |  oxapampa
# Processing Record 357 |  nome
# Processing Record 358 |  juneau
# Processing Record 359 |  chiredzi
# Processing Record 360 |  mendoza
# Processing Record 361 |  pandan
# Processing Record 362 |  mangrol
# Processing Record 363 |  maryville
# Processing Record 364 |  dalinghe
# Couldn't locate data. Skipping city!
# Processing Record 365 |  alvorada
# Processing Record 366 |  tuktoyaktuk
# Processing Record 367 |  viligili
# Couldn't locate data. Skipping city!
# Processing Record 368 |  la ronge
# Processing Record 369 |  san jeronimo
# Processing Record 370 |  fort saint john
# Couldn't locate data. Skipping city!
# Processing Record 371 |  ossora
# Processing Record 372 |  gurskoye
# Couldn't locate data. Skipping city!
# Processing Record 373 |  taoudenni
# Processing Record 374 |  lingdong
# Processing Record 375 |  lagoa
# Processing Record 376 |  leningradskiy
# Processing Record 377 |  kupang
# Processing Record 378 |  presidencia roque saenz pena
# Processing Record 379 |  qeshm
# Processing Record 380 |  mezen
# Processing Record 381 |  fuyu
# Processing Record 382 |  ribeira grande
# Processing Record 383 |  kloulklubed
# Processing Record 384 |  sol-iletsk
# Processing Record 385 |  luancheng
# Processing Record 386 |  ous
# Processing Record 387 |  nuuk
# Processing Record 388 |  lorengau
# Processing Record 389 |  povenets
# Processing Record 390 |  kulhudhuffushi
# Processing Record 391 |  cleveland
# Processing Record 392 |  cam pha
# Couldn't locate data. Skipping city!
# Processing Record 393 |  lodja
# Processing Record 394 |  usak
# Processing Record 395 |  namatanai
# Processing Record 396 |  ponta do sol
# Processing Record 397 |  ulladulla
# Processing Record 398 |  gainesville
# Processing Record 399 |  bolungarvik
# Couldn't locate data. Skipping city!
# Processing Record 400 |  marsa matruh
# Processing Record 401 |  inuvik
# Processing Record 402 |  grootfontein
# Processing Record 403 |  lanzhou
# Processing Record 404 |  soma
# Processing Record 405 |  san patricio
# Processing Record 406 |  manono
# Processing Record 407 |  santana do acarau
# Processing Record 408 |  at-bashi
# Processing Record 409 |  ostersund
# Processing Record 410 |  khani
# Processing Record 411 |  arak
# Processing Record 412 |  quelimane
# Processing Record 413 |  mazamari
# Processing Record 414 |  shenjiamen
# Processing Record 415 |  taltal
# Processing Record 416 |  algeciras
# Processing Record 417 |  tonj
# Processing Record 418 |  port hardy
# Processing Record 419 |  wapakoneta
# Processing Record 420 |  ancud
# Processing Record 421 |  ughelli
# Processing Record 422 |  jalu
# Processing Record 423 |  buesaco
# Processing Record 424 |  nenjiang
# Processing Record 425 |  richards bay
# Processing Record 426 |  oxford
# Processing Record 427 |  zapolyarnyy
# Processing Record 428 |  dryden
# Processing Record 429 |  naze
# Processing Record 430 |  kuusamo
# Processing Record 431 |  port moresby
# Processing Record 432 |  iguaba grande
# Processing Record 433 |  usinsk
# Processing Record 434 |  cayenne
# Processing Record 435 |  balabac
# Processing Record 436 |  ugoofaaru
# Processing Record 437 |  norman wells
# Processing Record 438 |  husavik
# Processing Record 439 |  verkhnevilyuysk
# Processing Record 440 |  fort-shevchenko
# Processing Record 441 |  maniitsoq
# Processing Record 442 |  hofn
# Processing Record 443 |  valdivia
# Processing Record 444 |  auki
# Processing Record 445 |  semey
# Processing Record 446 |  omboue
# Processing Record 447 |  lephepe
# Couldn't locate data. Skipping city!
# Processing Record 448 |  mulki
# Processing Record 449 |  puno
# Processing Record 450 |  uyuni
# Processing Record 451 |  wageningen
# Processing Record 452 |  mount gambier
# Processing Record 453 |  ozinki
# Processing Record 454 |  klaksvik
# Processing Record 455 |  jacqueville
# Processing Record 456 |  mormugao
# Processing Record 457 |  paamiut
# Processing Record 458 |  namibe
# Processing Record 459 |  urdzhar
# Couldn't locate data. Skipping city!
# Processing Record 460 |  uray
# Processing Record 461 |  erzin
# Processing Record 462 |  carutapera
# Processing Record 463 |  kurumkan
# Processing Record 464 |  college
# Processing Record 465 |  gribanovskiy
# Processing Record 466 |  tevaitoa
# Processing Record 467 |  henderson
# Processing Record 468 |  lolua
# Couldn't locate data. Skipping city!
# Processing Record 469 |  souillac
# Processing Record 470 |  pangody
# Processing Record 471 |  takoradi
# Processing Record 472 |  ca mau
# Processing Record 473 |  sembakung
# Processing Record 474 |  bagdarin
# Processing Record 475 |  kavieng
# Processing Record 476 |  bulgan
# Processing Record 477 |  maimon
# Couldn't locate data. Skipping city!
# Processing Record 478 |  pitimbu
# Processing Record 479 |  luanda
# Processing Record 480 |  koumac
# Processing Record 481 |  broken hill
# Processing Record 482 |  tilichiki
# Processing Record 483 |  beyneu
# Processing Record 484 |  kontagora
# Processing Record 485 |  leticia
# Processing Record 486 |  rosario oeste
# Processing Record 487 |  mitchell
# Processing Record 488 |  iquique
# Processing Record 489 |  poso
# Processing Record 490 |  agirish
# Processing Record 491 |  rundu
# Processing Record 492 |  turukhansk
# Processing Record 493 |  baykit
# Processing Record 494 |  mackay
# Processing Record 495 |  narsaq
# Processing Record 496 |  umzimvubu
# Couldn't locate data. Skipping city!
# Processing Record 497 |  dukat
# Processing Record 498 |  kalispell
# Processing Record 499 |  bengkulu
# Processing Record 500 |  curaca
# Processing Record 501 |  seminole
# Processing Record 502 |  vung tau
# Processing Record 503 |  te anau
# Processing Record 504 |  assis
# Processing Record 505 |  pawai
# Processing Record 506 |  polis
# Processing Record 507 |  rio gallegos
# Processing Record 508 |  san carlos de bariloche
# Processing Record 509 |  bongandanga
# Processing Record 510 |  salina cruz
# Processing Record 511 |  ellisras
# Processing Record 512 |  deogarh
# Processing Record 513 |  gavle
# Processing Record 514 |  gondanglegi
# Processing Record 515 |  north bend
# Processing Record 516 |  puerto rondon
# Processing Record 517 |  timmins
# Processing Record 518 |  sorland
# Processing Record 519 |  lata
# Processing Record 520 |  rudnogorsk
# Processing Record 521 |  villa carlos paz
# Processing Record 522 |  bargal
# Couldn't locate data. Skipping city!
# Processing Record 523 |  vao
# Processing Record 524 |  phrai bung
# Couldn't locate data. Skipping city!
# Processing Record 525 |  yaan
# Processing Record 526 |  mae hong son
# Processing Record 527 |  yirol
# Couldn't locate data. Skipping city!
# Processing Record 528 |  mananjary
# Processing Record 529 |  ulaangom
# Processing Record 530 |  lavrentiya
# Processing Record 531 |  ampanihy
# Processing Record 532 |  winneba
# Processing Record 533 |  malkangiri
# Processing Record 534 |  novosokolniki
# Processing Record 535 |  barcelona
# Processing Record 536 |  goderich
# Processing Record 537 |  xai-xai
# Processing Record 538 |  cuyo
# Processing Record 539 |  new richmond
# Processing Record 540 |  taguatinga
# Processing Record 541 |  kristiinankaupunki
# Processing Record 542 |  goffstown
# Processing Record 543 |  avera
# Processing Record 544 |  peniche
# Processing Record 545 |  stornoway
# Processing Record 546 |  honningsvag
# Processing Record 547 |  kruisfontein
# Processing Record 548 |  nanortalik
# Processing Record 549 |  nouadhibou
# Processing Record 550 |  asyut
# Processing Record 551 |  fort frances
# Processing Record 552 |  pakxan
# Processing Record 553 |  tungkang
# Couldn't locate data. Skipping city!
# Processing Record 554 |  saint-prosper
# Processing Record 555 |  bjala
# Couldn't locate data. Skipping city!
# Processing Record 556 |  xingyi
# Processing Record 557 |  aketi
# Processing Record 558 |  saint-augustin
# Processing Record 559 |  tiruvallur
# Processing Record 560 |  san matias
# Processing Record 561 |  praia da vitoria
# Processing Record 562 |  daru
# Processing Record 563 |  sitka
# Processing Record 564 |  borgosesia
# Processing Record 565 |  eyrarbakki
# Processing Record 566 |  canning
# Processing Record 567 |  miajadas
# Processing Record 568 |  mvangue
# Processing Record 569 |  kedgwick
# Processing Record 570 |  muros
# Processing Record 571 |  mandalgovi
# Processing Record 572 |  panama city
# Processing Record 573 |  benguela
# Processing Record 574 |  lamar
# Processing Record 575 |  roald
# Processing Record 576 |  dakar
# Processing Record 577 |  bangui
# Processing Record 578 |  saint-joseph
# Processing Record 579 |  rochegda
# Processing Record 580 |  tumannyy
# Couldn't locate data. Skipping city!
# Processing Record 581 |  olafsvik
# Processing Record 582 |  belyy yar
# Processing Record 583 |  belaya gora
# Processing Record 584 |  nueve de julio
# Processing Record 585 |  taldan
# Processing Record 586 |  koslan
# Processing Record 587 |  kharp
# Processing Record 588 |  lynn haven
# Processing Record 589 |  skoghall
# Processing Record 590 |  jumla
# Processing Record 591 |  magistralnyy
# Processing Record 592 |  wembley
# Processing Record 593 |  imbituba
# Processing Record 594 |  denpasar
# Processing Record 595 |  saint-leu
# Processing Record 596 |  krasnaya yaruga
# Processing Record 597 |  kvam
# Processing Record 598 |  cabedelo
# Processing Record 599 |  margate
# Processing Record 600 |  duekoue
# Processing Record 601 |  yurimaguas
# Processing Record 602 |  bruggen
# Processing Record 603 |  mamallapuram
# Processing Record 604 |  kapit
# Processing Record 605 |  bismarck
# Processing Record 606 |  progreso
# Processing Record 607 |  bayonet point
# Processing Record 608 |  torrington
# Processing Record 609 |  saint-francois
# Processing Record 610 |  senica
# Processing Record 611 |  cap malheureux
# Processing Record 612 |  ngukurr
# Couldn't locate data. Skipping city!
# Processing Record 613 |  torzhok
# Processing Record 614 |  kindu
# Processing Record 615 |  ambatofinandrahana
# Processing Record 616 |  raga
# Processing Record 617 |  flin flon
# Processing Record 618 |  kill
# Processing Record 619 |  middelkerke
# Processing Record 620 |  lunglei
# Processing Record 621 |  alexander city
# Processing Record 622 |  berdigestyakh
# Processing Record 623 |  san quintin
# Processing Record 624 |  labutta
# Couldn't locate data. Skipping city!
# Processing Record 625 |  salalah
# Processing Record 626 |  ravar
# Processing Record 627 |  old town
# Processing Record 628 |  magadan
# Processing Record 629 |  mackenzie
# Processing Record 630 |  pacific grove
# Processing Record 631 |  darlawn
# Processing Record 632 |  katobu
# Processing Record 633 |  nakhon phanom
# Processing Record 634 |  pakxe
# Processing Record 635 |  galesong
# Processing Record 636 |  yar-sale
# Processing Record 637 |  hanna
# Processing Record 638 |  piacabucu
# Processing Record 639 |  khagrachari
# Couldn't locate data. Skipping city!
# Processing Record 640 |  senges
# Processing Record 641 |  helena
# Processing Record 642 |  umm lajj
# Processing Record 643 |  basco
# Processing Record 644 |  colares
# Processing Record 645 |  bom jesus
# Processing Record 646 |  bystryy istok
# Processing Record 647 |  cuichapa
# Processing Record 648 |  alta floresta
# Processing Record 649 |  gat
# Processing Record 650 |  amahai
# Processing Record 651 |  chiang klang
# Processing Record 652 |  mulege
# Processing Record 653 |  sovetskiy

# %%
weather_reports.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         bluff          22      NZ  1592429203        83 -46.60  168.33
# 1  punta arenas           0      CL  1592429489        84 -53.15  -70.92
# 2       mataura           0      NZ  1592429194        83 -46.19  168.86
# 3           gap           0      FR  1592429490        78  44.67    6.00
# 4       kahului          20      US  1592429490        43  20.89 -156.47
#
#   Max Temp Wind Speeds
# 0    39.00        3.00
# 1    32.00        2.24
# 2    39.00        3.00
# 3    53.01        3.00
# 4    89.60       23.04

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_reports.to_csv("weather_reports.csv")
weather_reports.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         bluff          22      NZ  1592429203        83 -46.60  168.33
# 1  punta arenas           0      CL  1592429489        84 -53.15  -70.92
# 2       mataura           0      NZ  1592429194        83 -46.19  168.86
# 3           gap           0      FR  1592429490        78  44.67    6.00
# 4       kahului          20      US  1592429490        43  20.89 -156.47
#
#   Max Temp Wind Speeds
# 0    39.00        3.00
# 1    32.00        2.24
# 2    39.00        3.00
# 3    53.01        3.00
# 4    89.60       23.04

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
converted_dates = []
for date in dates:
    converted_date = datetime.datetime.fromtimestamp(date).strftime("%m/%d/%Y")
    converted_dates.append(converted_date)
    
weather_reports["Converted Date"] = converted_dates
weather_reports = weather_reports[["City", 
                                   "Cloudiness", 
                                   "Country", 
                                   "Date", 
                                   "Converted Date", 
                                   "Humidity", 
                                   "Lat", 
                                   "Lng", 
                                   "Max Temp", 
                                   "Wind Speeds"]]
plot_date = weather_reports.loc[0, "Converted Date"]
plt.scatter(weather_reports["Lat"], weather_data["Max Temp"], facecolor="#66CDAA", edgecolor="black")
plt.title(f"City Latitude vs. Max Temperature ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig('Lat_vs_Temp.png', dpi=300)
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and their maximum temperatures, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and their maximum temperatures, as recorded on June 14, 2020.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_reports["Lat"], weather_data["Humidity"], facecolor="#E3CF57", edgecolor="salmon")
plt.title(f"City Latitude vs. Humidity ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig('Latitude vs. Humidity Plot.png', dpi=300)
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and their humidity, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and their humidity, as recorded on June 14, 2020.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_reports["Lat"], weather_data["Cloudiness"], facecolor="#838B8B", edgecolor="darkolivegreen")
plt.title(f"City Latitude vs. Cloudiness ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig('Latitude vs. Cloudiness Plot.png', dpi=300)
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and their cloudiness, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and their cloudiness, as recorded on June 14, 2020.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_reports["Lat"], weather_data["Wind Speeds"], facecolor="#6495ED", edgecolor="orchid")
plt.title(f"City Latitude vs. Wind Speeds ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig('Latitude vs. Wind Speed Plot.png', dpi=300)
plt.show()
print("The above scatter plot shows the relationship between the latitude of cities and wind speeds, as recorded on June 14, 2020.")
# Out:
# The above scatter plot shows the relationship between the latitude of cities and wind speeds, as recorded on June 14, 2020.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
#weather_reports.head()

# Northern DF
northern_df = weather_reports.loc[weather_reports["Lat"] > 0,:]


# Southern DF
southern_df = weather_reports.loc[weather_reports["Lat"] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Max Temp"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(30,10),fontsize=15,color="red")

# Make Labels
plt.xlabel("Max Temp (F)")
plt.ylabel("Latitude")
plt.savefig('Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png', dpi=300)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Max Temp"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(32,-5),fontsize=15,color="red")

# Make Labels
plt.xlabel("Max Temp (F)")
plt.ylabel("Latitude")
plt.savefig('Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png', dpi=300)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Humidity"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(10,3),fontsize=15,color="red")

# Make Labels
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.savefig('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png', dpi=300)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Humidity"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(20,-55),fontsize=15,color="red")

# Make Labels
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.savefig('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png', dpi=300)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Cloudiness"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(40,75),fontsize=15,color="red")

# Make Labels
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.savefig('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png', dpi=300)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Cloudiness"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(20,-50),fontsize=15,color="red")

# Make Labels
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.savefig('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png', dpi=300)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = northern_df["Wind Speeds"].astype(float)
y_values = northern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(18,25),fontsize=15,color="red")

# Make Labels
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.savefig('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png', dpi=300)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set X and Y vals
x_values = southern_df["Wind Speeds"].astype(float)
y_values = southern_df["Lat"].astype(float)

# Run regression
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
# print(regress_values)

# To add regress line to your plot:
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# To add the equation to your plot:
plt.annotate(line_eq,(7,-50),fontsize=15,color="red")

# Make Labels
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.savefig('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png', dpi=300)
plt.show()
